# %%
# %%capture
# !wget https://drive.google.com/file/d/1T5fE1Se0CtFJ7v2Mzw0M7sRLtu-nAzsY/view?usp=sharing

# %%
# !gdown 1T5fE1Se0CtFJ7v2Mzw0M7sRLtu-nAzsY
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1T5fE1Se0CtFJ7v2Mzw0M7sRLtu-nAzsY
# To: /content/salaries_cyber.csv
# 100% 79.1k/79.1k [00:00<00:00, 3.90MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/salaries_cyber.csv')

# %%
df['Высокая зарплата'] = (df['remote_ratio'] > 50)

# %%
df[['remote_ratio', 'Высокая зарплата']]
# Out:
#       remote_ratio  Высокая зарплата
# 0               50             False
# 1                0             False
# 2                0             False
# 3               50             False
# 4              100              True
# ...            ...               ...
# 1242            50             False
# 1243            50             False
# 1244           100              True
# 1245           100              True
# 1246             0             False
#
# [1247 rows x 2 columns]
